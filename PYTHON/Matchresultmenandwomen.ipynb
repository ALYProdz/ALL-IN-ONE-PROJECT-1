# %% [markdown]
# You're working as a sports journalist at a major online sports media company, specializing in soccer analysis and reporting. You've been watching both men's and women's international soccer matches for a number of years, and your gut instinct tells you that more goals are scored in women's international football matches than men's. This would make an interesting investigative article that your subscribers are bound to love, but you'll need to perform a valid statistical hypothesis test to be sure!
#
# While scoping this project, you acknowledge that the sport has changed a lot over the years, and performances likely vary a lot depending on the tournament, so you decide to limit the data used in the analysis to only official `FIFA World Cup` matches (not including qualifiers) since `2002-01-01`.
#
# You create two datasets containing the results of every official men's and women's international football match since the 19th century, which you scraped from a reliable online source. This data is stored in two CSV files: `women_results.csv` and `men_results.csv`.
#
# The question you are trying to determine the answer to is:
#
# > Are more goals scored in women's international soccer matches than men's?
#
# You assume a **10% significance level**, and use the following null and alternative hypotheses:
#
# $H_0$ : The mean number of goals scored in women's international soccer matches is the same as men's.
#
# $H_A$ : The mean number of goals scored in women's international soccer matches is greater than men's.

# %% [markdown]
# <h1>Match Results men and women</h1>
# <p>In this analysis, we are going to analyse a crimes data from california city. Our objectives are :
# <ol>
#     ["date"] > "2002-01-01") & (men["tournament"].isin(["FIFA World Cup"]))]
#     <li>Find infomation about the data in 2002 and "FIFA WORLD CUP tournament" for men and Women".</li>
#     <li>Create a subset data for men and for women</li>
# </ol>
# </p>
# <p class = "Intro"> <h2>Step of the Analysis</h2></p>
# <ol>
#     <li>Import the important and necessary module and library for this Case Study</li>
#     <li>Import the data into data fram</li>
#     <li>Analyse the data
#     <ul>
#         <li>Check the shape of the Data</li>
#         <li>All the columns of the Data</li>
#         <li>Describe and Summarize the Data</li>
#         <li>All info about the Data</li>
#         <li>Data types of each columns</li>
#         <li>Select all numerical column and categorical columns</li>
#     </ul>
#     </li>
#     <li>  <h3>Data Cleaning and Processing</h3>
#         <p>In this section, we perform the following steps:
#         <ul>
#         <li>Check for missing value in the Data</li>
#         <li>Drop all missing value </li>
#         <li>Convert the columns to the corect Data types</li>
#         <li>Count the value in each column</li>
#         <li>Group the Data into category if necessary
#         </li>
#         <li>Number of unique Data in columns</li>
#             <li>Sort the Data if needed</li>
#         </ul> <br>
#         It's important to note that many notebook creators may encounter issues when numeric values are stored as strings with commas. Our approach using the str.replace method followed by pd.to_numeric is robust in handling such errors. <br>
#         We have to convert the occurent time into date time per hours, minutes.
#         </p>
#     </li>
#     <li><h3>Exploratory Data</h3>
#     <ul>
#         <h4>Visualize the Data</h4>
#     <li>Victims per ages</li>
#     </ul>
#     </li>
# </ol>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
from sklearn.linear_model import LinearRegression, LogisticRegression
import seaborn as sns
import scipy.stats as ss
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
men = pd.read_csv("./Desktop/DATA ANALYSIS PROJECT/Project/workspace (3)/workspace/men_results.csv")
women = pd.read_csv("./Desktop/DATA ANALYSIS PROJECT/Project/workspace (3)/workspace/women_results.csv")

# %% [markdown]
# ## EDA

# %%
men
# Out:
#        Unnamed: 0        date  home_team    away_team  home_score  away_score  \
# 0               0  1872-11-30   Scotland      England           0           0
# 1               1  1873-03-08    England     Scotland           4           2
# 2               2  1874-03-07   Scotland      England           2           1
# 3               3  1875-03-06    England     Scotland           2           2
# 4               4  1876-03-04   Scotland      England           3           0
# ...           ...         ...        ...          ...         ...         ...
# 44348       44348  2022-12-14   Thailand       Taiwan           0           1
# 44349       44349  2022-12-14    Vietnam  Philippines           1           0
# 44350       44350  2022-12-17    Croatia      Morocco           2           1
# 44351       44351  2022-12-17  Singapore     Maldives           3           1
# 44352       44352  2022-12-18  Argentina       France           3           3
#
#            tournament
# 0            Friendly
# 1            Friendly
# 2            Friendly
# 3            Friendly
# 4            Friendly
# ...               ...
# 44348        Friendly
# 44349        Friendly
# 44350  FIFA World Cup
# 44351        Friendly
# 44352  FIFA World Cup
#
# [44353 rows x 7 columns]

# %%
women
# Out:
#       Unnamed: 0        date home_team    away_team  home_score  away_score  \
# 0              0  1969-11-01     Italy       France           1           0
# 1              1  1969-11-01   Denmark      England           4           3
# 2              2  1969-11-02   England       France           2           0
# 3              3  1969-11-02     Italy      Denmark           3           1
# 4              4  1975-08-25  Thailand    Australia           3           2
# ...          ...         ...       ...          ...         ...         ...
# 4879        4879  2022-07-22    Sweden      Belgium           1           0
# 4880        4880  2022-07-23    France  Netherlands           1           0
# 4881        4881  2022-07-26   England       Sweden           4           0
# 4882        4882  2022-07-27   Germany       France           2           1
# 4883        4883  2022-07-31   England      Germany           2           1
#
#             tournament
# 0                 Euro
# 1                 Euro
# 2                 Euro
# 3                 Euro
# 4     AFC Championship
# ...                ...
# 4879         UEFA Euro
# 4880         UEFA Euro
# 4881         UEFA Euro
# 4882         UEFA Euro
# 4883         UEFA Euro
#
# [4884 rows x 7 columns]

# %%
men.shape
# Out:
# (44353, 7)

# %%
men.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44353 entries, 0 to 44352
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  44353 non-null  int64
#  1   date        44353 non-null  datetime64[ns]
#  2   home_team   44353 non-null  object
#  3   away_team   44353 non-null  object
#  4   home_score  44353 non-null  int64
#  5   away_score  44353 non-null  int64
#  6   tournament  44353 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 2.4+ MB

# %%
men.describe().T
# Out:
#               count                           mean                  min  \
# Unnamed: 0  44353.0                        22176.0                  0.0
# date          44353  1992-06-23 17:28:36.763240320  1872-11-30 00:00:00
# home_score  44353.0                       1.740559                  0.0
# away_score  44353.0                       1.178793                  0.0
#
#                             25%                  50%                  75%  \
# Unnamed: 0              11088.0              22176.0              33264.0
# date        1979-05-13 00:00:00  1999-03-11 00:00:00  2011-03-25 00:00:00
# home_score                  1.0                  1.0                  2.0
# away_score                  0.0                  1.0                  2.0
#
#                             max           std
# Unnamed: 0              44352.0  12803.752581
# date        2022-12-18 00:00:00           NaN
# home_score                 31.0      1.748722
# away_score                 21.0       1.39458

# %%
men.dtypes
# Out:
# Unnamed: 0             int64
# date          datetime64[ns]
# home_team             object
# away_team             object
# home_score             int64
# away_score             int64
# tournament            object
# dtype: object

# %%
men.values
# Out:
# array([[0, Timestamp('1872-11-30 00:00:00'), 'Scotland', ..., 0, 0,
#         'Friendly'],
#        [1, Timestamp('1873-03-08 00:00:00'), 'England', ..., 4, 2,
#         'Friendly'],
#        [2, Timestamp('1874-03-07 00:00:00'), 'Scotland', ..., 2, 1,
#         'Friendly'],
#        ...,
#        [44350, Timestamp('2022-12-17 00:00:00'), 'Croatia', ..., 2, 1,
#         'FIFA World Cup'],
#        [44351, Timestamp('2022-12-17 00:00:00'), 'Singapore', ..., 3, 1,
#         'Friendly'],
#        [44352, Timestamp('2022-12-18 00:00:00'), 'Argentina', ..., 3, 3,
#         'FIFA World Cup']], dtype=object)

# %%
men.value_counts()
# Out:
# Unnamed: 0  date        home_team     away_team       home_score  away_score  tournament
# 0           1872-11-30  Scotland      England         0           0           Friendly                                1
# 29573       2007-06-02  Wales         Czech Republic  0           0           UEFA Euro qualification                 1
# 29565       2007-06-02  Slovenia      Romania         1           2           UEFA Euro qualification                 1
# 29566       2007-06-02  South Africa  Chad            4           0           African Cup of Nations qualification    1
# 29567       2007-06-02  Sudan         Mauritius       3           0           African Cup of Nations qualification    1
#                                                                                                                      ..
# 14785       1987-04-08  Gabon         Ivory Coast     1           0           Friendly                                1
# 14786       1987-04-08  Romania       Israel          3           2           Friendly                                1
# 14787       1987-04-10  Bahrain       Iraq            1           2           Friendly                                1
# 14788       1987-04-11  Angola        DR Congo        1           0           African Cup of Nations qualification    1
# 44352       2022-12-18  Argentina     France          3           3           FIFA World Cup                          1
# Name: count, Length: 44353, dtype: int64

# %%
women.shape
# Out:
# (4884, 7)

# %%
women.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4884 entries, 0 to 4883
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4884 non-null   int64
#  1   date        4884 non-null   datetime64[ns]
#  2   home_team   4884 non-null   object
#  3   away_team   4884 non-null   object
#  4   home_score  4884 non-null   int64
#  5   away_score  4884 non-null   int64
#  6   tournament  4884 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 267.2+ KB

# %%
women.describe().T
# Out:
#              count                           mean                  min  \
# Unnamed: 0  4884.0                         2441.5                  0.0
# date          4884  2007-08-17 22:29:11.351351296  1969-11-01 00:00:00
# home_score  4884.0                       2.272727                  0.0
# away_score  4884.0                       1.431409                  0.0
#
#                             25%                  50%                  75%  \
# Unnamed: 0              1220.75               2441.5              3662.25
# date        2000-06-23 00:00:00  2009-07-13 00:00:00  2016-04-12 00:00:00
# home_score                  0.0                  1.0                  3.0
# away_score                  0.0                  1.0                  2.0
#
#                             max          std
# Unnamed: 0               4883.0  1410.033688
# date        2022-07-31 00:00:00          NaN
# home_score                 24.0     2.736377
# away_score                 24.0     1.974651

# %%
women.value_counts()
# Out:
# Unnamed: 0  date        home_team      away_team            home_score  away_score  tournament
# 0           1969-11-01  Italy          France               1           0           Euro                       1
# 3254        2014-03-12  North Korea    United States        0           3           Algarve Cup                1
# 3261        2014-03-12  Canada         Republic of Ireland  2           1           Cyprus Cup                 1
# 3260        2014-03-12  Italy          Australia            2           5           Cyprus Cup                 1
# 3259        2014-03-12  Netherlands    Switzerland          4           1           Cyprus Cup                 1
#                                                                                                               ..
# 1626        2003-09-28  United States  North Korea          3           0           FIFA World Cup             1
# 1625        2003-09-28  Sweden         Nigeria              3           0           FIFA World Cup             1
# 1624        2003-09-28  Croatia        Malta                3           0           UEFA Euro qualification    1
# 1623        2003-09-27  Argentina      Germany              1           6           FIFA World Cup             1
# 4883        2022-07-31  England        Germany              2           1           UEFA Euro                  1
# Name: count, Length: 4884, dtype: int64

# %%
women.values
# Out:
# array([[0, Timestamp('1969-11-01 00:00:00'), 'Italy', ..., 1, 0, 'Euro'],
#        [1, Timestamp('1969-11-01 00:00:00'), 'Denmark', ..., 4, 3,
#         'Euro'],
#        [2, Timestamp('1969-11-02 00:00:00'), 'England', ..., 2, 0,
#         'Euro'],
#        ...,
#        [4881, Timestamp('2022-07-26 00:00:00'), 'England', ..., 4, 0,
#         'UEFA Euro'],
#        [4882, Timestamp('2022-07-27 00:00:00'), 'Germany', ..., 2, 1,
#         'UEFA Euro'],
#        [4883, Timestamp('2022-07-31 00:00:00'), 'England', ..., 2, 1,
#         'UEFA Euro']], dtype=object)

# %%
women.dtypes
# Out:
# Unnamed: 0             int64
# date          datetime64[ns]
# home_team             object
# away_team             object
# home_score             int64
# away_score             int64
# tournament            object
# dtype: object

# %%
women.columns
# Out:
# Index(['Unnamed: 0', 'date', 'home_team', 'away_team', 'home_score',
#        'away_score', 'tournament'],
#       dtype='object')

# %%
men.columns
# Out:
# Index(['Unnamed: 0', 'date', 'home_team', 'away_team', 'home_score',
#        'away_score', 'tournament'],
#       dtype='object')

# %% [markdown]
# ## Data Wrangling

# %%
men.drop("Unnamed: 0", axis = 1, inplace= True)

# %%
men
# Out:
#             date  home_team    away_team  home_score  away_score  \
# 0     1872-11-30   Scotland      England           0           0
# 1     1873-03-08    England     Scotland           4           2
# 2     1874-03-07   Scotland      England           2           1
# 3     1875-03-06    England     Scotland           2           2
# 4     1876-03-04   Scotland      England           3           0
# ...          ...        ...          ...         ...         ...
# 44348 2022-12-14   Thailand       Taiwan           0           1
# 44349 2022-12-14    Vietnam  Philippines           1           0
# 44350 2022-12-17    Croatia      Morocco           2           1
# 44351 2022-12-17  Singapore     Maldives           3           1
# 44352 2022-12-18  Argentina       France           3           3
#
#            tournament
# 0            Friendly
# 1            Friendly
# 2            Friendly
# 3            Friendly
# 4            Friendly
# ...               ...
# 44348        Friendly
# 44349        Friendly
# 44350  FIFA World Cup
# 44351        Friendly
# 44352  FIFA World Cup
#
# [44353 rows x 6 columns]

# %%
women.drop("Unnamed: 0", axis = 1, inplace= True)

# %%
women
# Out:
#            date home_team    away_team  home_score  away_score  \
# 0    1969-11-01     Italy       France           1           0
# 1    1969-11-01   Denmark      England           4           3
# 2    1969-11-02   England       France           2           0
# 3    1969-11-02     Italy      Denmark           3           1
# 4    1975-08-25  Thailand    Australia           3           2
# ...         ...       ...          ...         ...         ...
# 4879 2022-07-22    Sweden      Belgium           1           0
# 4880 2022-07-23    France  Netherlands           1           0
# 4881 2022-07-26   England       Sweden           4           0
# 4882 2022-07-27   Germany       France           2           1
# 4883 2022-07-31   England      Germany           2           1
#
#             tournament
# 0                 Euro
# 1                 Euro
# 2                 Euro
# 3                 Euro
# 4     AFC Championship
# ...                ...
# 4879         UEFA Euro
# 4880         UEFA Euro
# 4881         UEFA Euro
# 4882         UEFA Euro
# 4883         UEFA Euro
#
# [4884 rows x 6 columns]

# %%
men["date"] = pd.to_datetime(men["date"])
men_subset = men[(men["date"] > "2002-01-01") & (men["tournament"].isin(["FIFA World Cup"]))]
women["date"] = pd.to_datetime(women["date"])
women_subset = women[(women["date"] > "2002-01-01") & (women["tournament"].isin(["FIFA World Cup"]))]

# Create group and goals_scored columns
men_subset["group"] = "men"
women_subset["group"] = "women"
men_subset["goals_scored"] = men_subset["home_score"] + men_subset["away_score"]
women_subset["goals_scored"] = women_subset["home_score"] + women_subset["away_score"]
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_23860\4167868108.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   men_subset["group"] = "men"
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_23860\4167868108.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   women_subset["group"] = "women"
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_23860\4167868108.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   men_subset["goals_scored"] = men_subset["home_score"] + men_subset["away_score"]
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_23860\4167868108.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   women_subset["goals_scored"] = women_subset["home_score"] + women_subset["away_score"]

# %%
men_subset
# Out:
#             date            home_team     away_team  home_score  away_score  \
# 25164 2002-05-31               France       Senegal           0           1
# 25165 2002-06-01              Germany  Saudi Arabia           8           0
# 25166 2002-06-01  Republic of Ireland      Cameroon           1           1
# 25167 2002-06-01              Uruguay       Denmark           1           2
# 25168 2002-06-02            Argentina       Nigeria           1           0
# ...          ...                  ...           ...         ...         ...
# 44343 2022-12-10              England        France           1           2
# 44345 2022-12-13            Argentina       Croatia           3           0
# 44346 2022-12-14               France       Morocco           2           0
# 44350 2022-12-17              Croatia       Morocco           2           1
# 44352 2022-12-18            Argentina        France           3           3
#
#            tournament group  goals_scored
# 25164  FIFA World Cup   men             1
# 25165  FIFA World Cup   men             8
# 25166  FIFA World Cup   men             2
# 25167  FIFA World Cup   men             3
# 25168  FIFA World Cup   men             1
# ...               ...   ...           ...
# 44343  FIFA World Cup   men             3
# 44345  FIFA World Cup   men             3
# 44346  FIFA World Cup   men             2
# 44350  FIFA World Cup   men             3
# 44352  FIFA World Cup   men             6
#
# [384 rows x 8 columns]

# %%
women_subset
# Out:
#            date      home_team      away_team  home_score  away_score  \
# 1600 2003-09-20        Nigeria    North Korea           0           3
# 1601 2003-09-20         Norway         France           2           0
# 1602 2003-09-20        Germany         Canada           4           1
# 1603 2003-09-20          Japan      Argentina           6           0
# 1604 2003-09-21  United States         Sweden           3           1
# ...         ...            ...            ...         ...         ...
# 4465 2019-06-29        Germany         Sweden           1           2
# 4466 2019-07-02        England  United States           1           2
# 4467 2019-07-03    Netherlands         Sweden           1           0
# 4468 2019-07-06        England         Sweden           1           2
# 4469 2019-07-07  United States    Netherlands           2           0
#
#           tournament  group  goals_scored
# 1600  FIFA World Cup  women             3
# 1601  FIFA World Cup  women             2
# 1602  FIFA World Cup  women             5
# 1603  FIFA World Cup  women             6
# 1604  FIFA World Cup  women             4
# ...              ...    ...           ...
# 4465  FIFA World Cup  women             3
# 4466  FIFA World Cup  women             3
# 4467  FIFA World Cup  women             1
# 4468  FIFA World Cup  women             3
# 4469  FIFA World Cup  women             2
#
# [200 rows x 8 columns]

# %%
men
# Out:
#             date  home_team    away_team  home_score  away_score  \
# 0     1872-11-30   Scotland      England           0           0
# 1     1873-03-08    England     Scotland           4           2
# 2     1874-03-07   Scotland      England           2           1
# 3     1875-03-06    England     Scotland           2           2
# 4     1876-03-04   Scotland      England           3           0
# ...          ...        ...          ...         ...         ...
# 44348 2022-12-14   Thailand       Taiwan           0           1
# 44349 2022-12-14    Vietnam  Philippines           1           0
# 44350 2022-12-17    Croatia      Morocco           2           1
# 44351 2022-12-17  Singapore     Maldives           3           1
# 44352 2022-12-18  Argentina       France           3           3
#
#            tournament
# 0            Friendly
# 1            Friendly
# 2            Friendly
# 3            Friendly
# 4            Friendly
# ...               ...
# 44348        Friendly
# 44349        Friendly
# 44350  FIFA World Cup
# 44351        Friendly
# 44352  FIFA World Cup
#
# [44353 rows x 6 columns]

# %%
sns.catplot(data = men, x = "home_score", y = "away_score")

# %% [markdown]
# <h2>
#     Author :
#      <h6>WEDSON PETIT HOMME </h6>
#     <br>
#     <h4> Contact :</h4>
#     <li>Email : wedsonpetithomme0@gmail.com</li>
#     <li> <a href = "https://www.linkedin.com/"> Linkedin :</a><a href = "https://www.linkedin.com/in/wedson-petithomme-947571239/">wedson-petit-homme-947571239 </a></li>
#     <li><a href = "https://github.com/ALYProdz">GitHub :</a><a href = "https://github.com/ALYProdz">Wedson (ALYProdz) </a> </li>
#     <li><a href = "https://x.com/"> X(Twitter) :</a> @WedsonPh97</li>
#     <li><a href = https://www.datacamp.com/portfolio/wedsonpetithomme> Datacamp :</a><a href = "https://www.datacamp.com/portfolio/wedsonpetithomme"> WEDSON PETIT HOMME</a></li>
# </h2>
